# %% [markdown]
# ## Exercise 3: Uniprot
#
# Find the following information about your protein of interest:
#
# • Uniprot ID, protein Name, length, keywords, function
#
#     - **Uniprot ID**: P01112
#
#     - **Protein name**: GTPase HRas
#
#     - **Length**: 189
#
#     - **Keywords**: Hydrolase
#
#     - **Function**: Involved in the activation of Ras protein signal transduction. Ras proteins bind GDP/GTP and possess intrinsic GTPase activity
#
# • What domains are there? DNA-binding? Ligand-binding?
#
#     - **Effector region**:
#
#     - **Hypervariable region**:
#
#     - **Multiple Binding sites**: GTP (Ligand-binding)
#
# • Gene Ontology?
#
#     - Catalytic activity
#
#     - Enzyme regulator activity
#
#     - small molecule binding
#
#     - carbohydrate derivative binding
#
#     - immune system process
#
#     - cell cycle
#
#     - programmed cell death
#
#     - response to stimulus
#
#     - ... and many more
#
# • Which mutations & diseases?
#
#     - **Costello syndrome (CSTLO)**:
#
#         - Single-nucleotide misssense mutations at position 12, 13, 37 leading to a different amino acid
#
#     - **Thyroid cancer, non-medullary, 2 (NMTC2)**:
#
#         - Misssense mutation at position 61
#
#     - **Bladder cancer (BLC)**
#
#     - **Schimmelpenning-Feuerstein-Mims syndrome (SFM)**:
#
#         - Misssense mutation at position 13
#
# • Sub-cellular location?
#
#     - Cell-membrane
#
#     - Golgi-Apparatus
#
#     - Nucleus
#
#     - Cytoplasm
#
# • Which PTM?
#
#     Showing features for initiator methionine, modified residue, chain, glycosylation, modified residue (large scale data), cross-link, lipidation, propeptide.
#
# • Are there isoforms?
#
#     There are two isoforms:
#
#     - **P01112-1** (canonical)
#
#     - **P01112-2**: difference from canonical from 152-189
#
# • Orthologs / paralogs?
#
#     - Orthologs:
#
#         - Mus musculus 10/10
#
#         - Rattus norvegicus 9/10
#
#         - and many more...
#
#     - Paralogs:
#
#         - KRAS: similarity 95 and Identity 87
#
#         - NRAS: similarity 93 and identity 86
#
#         - and many more ...

# %% [markdown]
# ## Exercise 4: PDB
#
# Read https://pdb101.rcsb.org/learn/exploring-the-structural-biology-of-health-and-nutrition and use one of them as your protein of interest.
#
# • Download the PDBx file, from the file
#
# • Use this guide https://mmcif.wwpdb.org/docs/user-guide/guide.html
#
# • Find information about the citation, sequence, composition of macromolecules, mutation if any
#
# • Open the Structure Tab (3D viewer) Change the view to ball and stick,
#
# • Add annotation of 3rd modeled amino acid residue (Gray is unmodeled)
#
# • Find the PDB entry of hemoglobin structure that is wild type and mutation
#
# • Load them onto https://www.rcsb.org/3d-view/
#
# • Select by Chain (default: Residue)
#
# • Superimpose the mutated and wild type chain.
#
# • Look at the structural difference

# %% [markdown]
# Selected protein of interest: **2CRK Muscle Creatine Kinase**
#
# All the following data has been found in the PDBx file. Citations can be found at the beginning of the file. For finding the composition, search 'entity'.
#
# Citation:
#
#     loop_
#     _citation_author.citation_id
#     _citation_author.name
#     _citation_author.ordinal
#     _citation_author.identifier_ORCID
#     primary 'Rao, J.K.'    1 ?
#     primary 'Bujacz, G.'   2 ?
#     primary 'Wlodawer, A.' 3 ?
#
#
# Sequence: visible when opening the tab for 3D structure, but I was unable to copy the sequence in here
#
# Composition of macromulecules:
#
#     _entity.details
#     1 polymer     nat 'PROTEIN (CREATINE KINASE)' 43301.227
#     2 non-polymer syn 'SULFATE ION'               96.063
#     3 water       nat water                       18.015
#
#
# Mutations: NO

# %% [markdown]
# Wildtype hemoglobin = 5KSJ
# Mutant hemoglobin = 3QJB
#
# ### Workflow
#
# Load two in the tool
# Select by the chain and not by the residue
# Superposition -> view the two chains -> superimpose to compare
#
# ![image.png](attachment:image.png)
