# %% [markdown]
# # My expectations:
# My expectations for this course: to learn about different computational tools to analyze differences in sequences and how these may relate to disease. Also, I hope to improve my python skills, as I have previously only worked with C++.
# # general background knowledge
# I am a biochemistry student, so I have not had much experience with health and disease. However, the basics of cancer research and also informatics skills were taught.
# # knowledge of R
# I took Statistics II where we learned how to work with RStudio. Then in lab courses and systems biology we further improved our skills.
# # knowledge of python
# Quite limited, I only properly learned C++. However, over time I had a lot of courses that helped me be able to read and understand python codes.
# # different syntax
# **bold**
