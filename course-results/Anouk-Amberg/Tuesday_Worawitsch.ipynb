# %% [markdown]
# # IGV Exercise Answers

# %% [markdown]
# ---
# ## Part 1 — Work on Sample A
#
# Files used:
# - BAM: `A_sort_markdup_recal.bam`
# - VCF: `A.vcf`
# - Reference: Human GRCh38/hg38, chr14

# %% [markdown]
# ### Variant 1 — Moderate Impact
#
# | Property | Value |
# |----------|-------|
# | Position | chr14:XXXXXXX |
# | Variant type | SNP / Insertion / Deletion |
# | REF allele | X |
# | ALT allele | X |
# | Genotype | Heterozygous / Homozygous |
# | REF read count | X |
# | ALT read count | X |

# %% [markdown]
# ![Bild 03.05.26 um 11.55.jpeg](<attachment:Bild 03.05.26 um 11.55.jpeg>)

# %% [markdown]
# ### Variant 2 — Low Impact
#
# | Property | Value |
# |----------|-------|
# | Position | chr14:XXXXXXX |
# | Variant type | SNP / Insertion / Deletion |
# | REF allele | X |
# | ALT allele | X |
# | Genotype | Heterozygous / Homozygous |
# | REF read count | X |
# | ALT read count | X |

# %% [markdown]
# ![Bild 03.05.26 um 12.04.jpeg](<attachment:Bild 03.05.26 um 12.04.jpeg>)

# %% [markdown]
# ---
# ## Part 2 — Structural Variants in extracted_variants.bam
#
# Files used:
# - BAM: `extracted_variants.bam`
# - Reference: Human GRCh38/hg38

# %% [markdown]
# ### Region 1 — chr1:37350877-37351115
#
# **Structural variant type:** Deletion
#
# **Evidence:** A long read spanning the breakpoint is visible, indicating that sequence is missing between the two dashed lines. The read extends across the gap, which is characteristic of a deletion event.

# %% [markdown]
# ![Bild 02.05.26 um 21.59.jpeg](<attachment:Bild 02.05.26 um 21.59.jpeg>)

# %% [markdown]
# ### Region 2 — chr1:41369871-41369871
#
# **Structural variant type:** Translocation / Inversion
#
# **Evidence:** Cyan/teal colored reads are visible, indicating that their mate-pairs map to a different location in the genome. This is characteristic of a translocation or inversion event. The gene FOXO6 is located in this region.

# %% [markdown]
# ![Bild 02.05.26 um 22.59.jpeg](<attachment:Bild 02.05.26 um 22.59.jpeg>)

# %% [markdown]
# ### Region 3 — chr2:117564013-117572037
#
# **Structural variant type:** Translocation
#
# **Evidence:** Many reads with different colors (green, blue, purple, yellow, orange) are visible. In IGV, colored reads indicate that their mate-pairs map to different chromosomes or orientations. The variety of colors suggests a complex structural variation, consistent with a translocation event.

# %% [markdown]
# ![Bild 02.05.26 um 22.02.jpeg](<attachment:Bild 02.05.26 um 22.02.jpeg>)
