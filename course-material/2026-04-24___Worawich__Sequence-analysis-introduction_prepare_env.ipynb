# %% [markdown]
# ## Install program with conda
#
# **Set channel**

# %%
conda config --add channels bioconda
conda config --add channels conda-forge
conda config --set channel_priority strict

# %% [markdown]
# **Create conda environment**

# %%
conda create -n human_env

# %%
conda activate human_env

# %%
conda install fastqc fastp samtools bwa vcftools bcftools gatk4

# %% [markdown]
# ---
# **Create another environment**

# %%
conda deactivate

# %%
conda create -n sv_env

# %%
conda activate sv_env

# %%
conda install delly vcftools bcftools

# %% [markdown]
# ---
# ## Download main notebook
#
# The main notebook can download from this google drive link
#
# https://drive.google.com/file/d/1HRfHF1QP_e1WqH8gQ9mcVfNs1fRGTGke/view?usp=sharing
